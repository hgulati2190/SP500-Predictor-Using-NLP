# %% [markdown]
# # Model Explanation

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import shap

# %%
model = AutoModelForSequenceClassification.from_pretrained("jeroenvdmbrugge/sp500-predictor-individual-headlines")
tokenizer = AutoTokenizer.from_pretrained("jeroenvdmbrugge/sp500-predictor-individual-headlines")
pred = pipeline("text-classification", model=model, tokenizer=tokenizer, return_all_scores=True)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# /Users/jeroen/anaconda/lib/python3.12/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
explainer = shap.Explainer(pred, tokenizer)

# %%
sample_headlines = pd.read_csv("../data/jvdm_data_sources_trends.csv").sample(3, random_state=42).Headlines.values
sample_headlines
# Out:
# array(['Oil rises 1 percent on tightening crude supply , upbeat economic data',
#        "'Crash Monday' is the price we're paying for a decade of cheap money",
#        'IMF asks G20 to back doubling of its emergency financing to fight coronavirus'],
#       dtype=object)

# %%
shap_values = explainer(sample_headlines)
# Out:
# PartitionExplainer explainer:  67%|███████████████▎       | 2/3 [00:00<?, ?it/s]
#   0%|          | 0/342 [00:00<?, ?it/s]
# PartitionExplainer explainer: 4it [00:19,  9.75s/it]

# %%
shap.plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_tonfsvdquqprkavbsxdx = '_tp_tonfsvdquqprkavbsxdx_output_0';
#     document._zoom_tonfsvdquqprkavbsxdx = undefined;
#     function _output_onclick_tonfsvdquqprkavbsxdx(i) {
#         var next_id = undefined;
#
#         if (document._zoom_tonfsvdquqprkavbsxdx !== undefined) {
#             document.getElementById(document._zoom_tonfsvdquqprkavbsxdx+ '_zoom').style.display = 'none';
#
#             if (document._zoom_tonfsvdquqprkavbsxdx === '_tp_tonfsvdquqprkavbsxdx_output_' + i) {
#                 document.getElementById(document._zoom_tonfsvdquqprkavbsxdx).style.display = 'block';
#                 document.getElementById(document._zoom_tonfsvdquqprkavbsxdx+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_tonfsvdquqprkavbsxdx).style.display = 'none';
#                 document.getElementById(document._zoom_tonfsvdquqprkavbsxdx+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_tonfsvdquqprkavbsxdx !== '_tp_tonfsvdquqprkavbsxdx_output_' + i) {
#             next_id = '_tp_tonfsvdquqprkavbsxdx_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_tonfsvdquqprkavbsxdx = next_id;
#     }
#     function _output_onmouseover_tonfsvdquqprkavbsxdx(i, el) {
#         if (document._zoom_tonfsvdquqprkavbsxdx !== undefined) { return; }
#         if (document._hover_tonfsvdquqprkavbsxdx !== undefined) {
#             document.getElementById(document._hover_tonfsvdquqprkavbsxdx + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_tonfsvdquqprkavbsxdx).style.display = 'none';
#         }
#         document.getElementById('_tp_tonfsvdquqprkavbsxdx_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_tonfsvdquqprkavbsxdx = '_tp_tonfsvdquqprkavbsxdx_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.5349178055060405); border-radius: 3px; padding: 0px" id="_tp_tonfsvdquqprkavbsxdx_output_0_name"
#     onclick="_output_onclick_tonfsvdquqprkavbsxdx(0)"
#     onmouseover="_output_onmouseover_tonfsvdquqprkavbsxdx(0, this);">decrease</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_tonfsvdquqprkavbsxdx_output_1_name"
#     onclick="_output_onclick_tonfsvdquqprkavbsxdx(1)"
#     onmouseover="_output_onmouseover_tonfsvdquqprkavbsxdx(1, this);">maintain</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.5822142998613588); border-radius: 3px; padding: 0px" id="_tp_tonfsvdquqprkavbsxdx_output_2_name"
#     onclick="_output_onclick_tonfsvdquqprkavbsxdx(2)"
#     onmouseover="_output_onmouseover_tonfsvdquqprkavbsxdx(2, this);">increase</div><br><br><div id='_tp_tonfsvdquqprkavbsxdx_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="51.65314304172959%" y1="33" x2="51.65314304172959%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.65314304172959%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="34.76273125045209%" y1="33" x2="34.76273125045209%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.76273125045209%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="17.87231945917458%" y1="33" x2="17.87231945917458%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="17.87231945917458%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="68.54355483300711%" y1="33" x2="68.54355483300711%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.54355483300711%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="85.43396662428462%" y1="33" x2="85.43396662428462%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="85.43396662428462%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="41.30333291120405%" y1="33" x2="41.30333291120405%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="41.30333291120405%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.238724</text><text x="41.30333291120405%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.238724</text><text x="41.30333291120405%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="43.75227014504412%" y1="33" x2="43.75227014504412%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="43.75227014504412%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.253223</text><text x="43.75227014504412%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.253223</text><text x="43.75227014504412%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">decrease</tspan>(inputs)</text><rect x="29.79902106641206%" width="13.953249078632059%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="37.72707688702087%" x2="43.75227014504412%" y1="60" y2="60" id="_fb_woiskpjayfiakgrpbcyb_ind_8" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="40.7396735160325%" y="71" font-size="12px" id="_fs_woiskpjayfiakgrpbcyb_ind_8" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.036</text><svg x="37.72707688702087%" y="40" height="20" width="6.025193258023251%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">supply</text>  </svg></svg><line x1="33.46803498340678%" x2="37.72707688702087%" y1="60" y2="60" id="_fb_woiskpjayfiakgrpbcyb_ind_1" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="35.597555935213826%" y="71" font-size="12px" id="_fs_woiskpjayfiakgrpbcyb_ind_1" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle" ...
